# %% [markdown]
# <a href="https://colab.research.google.com/github/BuberDev/Artificial-Intelligence-ComputerVision/blob/main/Podstawowe_operacje_na_obrazach.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import cv2

# %%
import numpy as np

# %%
from google.colab.patches import cv2_imshow

# %%
import imutils

# %%
cv2.__version__
# Out:
# '4.6.0'

# %%
img = cv2.imread('bear.jpg')

# %%
cv2_imshow(img)
# Out:
# <PIL.Image.Image image mode=RGB size=586x480 at 0x7F29B7035C40>

# %%
img_resized = imutils.resize(image=img, height=300)

# %%
cv2_imshow(img_resized)
# Out:
# <PIL.Image.Image image mode=RGB size=366x300 at 0x7F29B5F2E340>

# %%
img_resized = imutils.resize(image=img, width=300)
cv2_imshow(img_resized)
# Out:
# <PIL.Image.Image image mode=RGB size=300x245 at 0x7F29B6F70A00>

# %% [markdown]
# ROTACJA

# %%
height, width = img.shape[:2]

# %%
M = cv2.getRotationMatrix2D(center=(height // 2, width // 2), angle=45, scale=1)
cv2_imshow(cv2.warpAffine(src=img, M=M, dsize=(width, height)))
# Out:
# <PIL.Image.Image image mode=RGB size=586x480 at 0x7F29B6FBF700>

# %%
M = cv2.getRotationMatrix2D(center=(height // 2, width // 2), angle=45, scale=0.5)
cv2_imshow(cv2.warpAffine(src=img, M=M, dsize=(width, height)))
# Out:
# <PIL.Image.Image image mode=RGB size=586x480 at 0x7F29B5F17730>

# %%
M = cv2.getRotationMatrix2D(center=(height // 2, width // 2), angle=-45, scale=0.8)
cv2_imshow(cv2.warpAffine(src=img, M=M, dsize=(width, height)))
# Out:
# <PIL.Image.Image image mode=RGB size=586x480 at 0x7F29B5F179A0>

# %%
gray = cv2.cvtColor(src=img, code=cv2.COLOR_BGR2GRAY)
cv2_imshow(gray)
# Out:
# <PIL.Image.Image image mode=L size=586x480 at 0x7F29B5F17040>

# %%
cv2_imshow(cv2.threshold(src=gray, thresh=125, maxval=255, type=cv2.THRESH_BINARY)[1])
# Out:
# <PIL.Image.Image image mode=L size=586x480 at 0x7F29B5F17700>

# %% [markdown]
# OPERACJA SPLOTU, WYGLADZENIE
